# %%
from chemsampler import ChemSampler
cs = ChemSampler()
example = cs.example()

# %%
example
# Out:
# ['CC1C2C(CC3(C=CC(=O)C(=C3C2OC1=O)C)C)O',
#  'C1=CN=CC=C1C(=O)NN',
#  'CC(CN1C=NC2=C(N=CN=C21)N)OCP(=O)(O)O',
#  'CC(=O)OC1=CC=CC=C1C(=O)O',
#  'CC(C)CC1=CC=C(C=C1)C(C)C(=O)O',
#  'CC1(OC2C(OC(C2O1)(C#N)C3=CC=C4N3N=CN=C4N)CO)C',
#  'COC1=CC23CCCN2CCC4=CC5=C(C=C4C3C1O)OCO5']

# %%
results = cs.sample(example)
# Out:
# ['CC1C2C(CC3(C=CC(=O)C(=C3C2OC1=O)C)C)O', 'C1=CN=CC=C1C(=O)NN', 'CC(CN1C=NC2=C(N=CN=C21)N)OCP(=O)(O)O', 'CC(=O)OC1=CC=CC=C1C(=O)O', 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)O', 'CC1(OC2C(OC(C2O1)(C#N)C3=CC=C4N3N=CN=C4N)CO)C', 'COC1=CC23CCCN2CCC4=CC5=C(C=C4C3C1O)OCO5']
# Using sampler: BimodalSampler
# bimodal_sampler
# 650
# Using sampler: BimodalSampler
# bimodal_sampler
# 1222
# 7it [00:00, 1102.69it/s]
# ['CC(CN1C=NC2=C(N=CN=C21)N)OCP(=O)(O)O', 'C1=CN=CC=C1C(=O)NN', 'COC1=CC23CCCN2CCC4=CC5=C(C=C4C3C1O)OCO5', 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)O', 'CC1(OC2C(OC(C2O1)(C#N)C3=CC=C4N3N=CN=C4N)CO)C', 'CC(=O)OC1=CC=CC=C1C(=O)O', 'CC1C2C(CC3(C=CC(=O)C(=C3C2OC1=O)C)C)O']
# Using sampler: MolerSampler
# moler_sampler
# 600
# Using sampler: MolerSampler
# moler_sampler
# 1193
# 7it [00:00, 661.01it/s]
# ...

# %%
results
# Out:
# {'BimodalSampler': [[], [], [], [], [], [], []],
#  'MolerSampler': [[], ['COC1=CC=CC=C1C(=O)O'], [], [], [], [], []],
#  'SmallWorldSampler': [['NNC(=O)C1=CC=NC=C1',
#    'CNC(=O)C1=CC=NC=C1',
#    'CONC(=O)C1=CC=NC=C1',
#    'NC(=O)C1=CC=NC=C1'],
#   ['CC(C)COC(=O)CN1C=NC2=C(N)N=CN=C21'],
#   [],
#   ['CC(C)CC1=CC=C(C(C)C(N)=O)C=C1',
#    'CC(C)CC1=CC=C([C@H](C)C(=O)NN)C=C1',
#    'CC(=NO)C(C)C1=CC=C(CC(C)C)C=C1'],
#   [],
#   [],
#   ['COC(=O)OC1=CC=CC=C1C(=O)O', 'CNC(=O)C1=CC=CC=C1OC(C)=O']]}

# %%
from chemsampler.samplers.stoned.sampler import StonedSampler

# %%
ss = StonedSampler()

# %%
stoned_results = ss.sample(example, n=1000)
# Out:
# Seed SMILES list: {'COC1=CC23CCCN2CCC4=CC5=C(C=C4C3C1O)OCO5', 'C1=CN=CC=C1C(=O)NN', 'CC(C)CC1=CC=C(C=C1)C(C)C(=O)O', 'CC1C2C(CC3(C=CC(=O)C(=C3C2OC1=O)C)C)O', 'CC1(OC2C(OC(C2O1)(C#N)C3=CC=C4N3N=CN=C4N)CO)C', 'CC(CN1C=NC2=C(N=CN=C21)N)OCP(=O)(O)O', 'CC(=O)OC1=CC=CC=C1C(=O)O'}
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1796/1796 [00:00<00:00, 19768.62it/s]
# 1262 molecules sampled. Selecting the best by similarity.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1262/1262 [00:00<00:00, 19127.23it/s]
# Molecules remaining 1262

# %%
stoned_results
# Out:
# ['C1(C(O)=O)=CC=CC=C1OC',
#  'O(C)C1=CC=CC=C1C(O)=O',
#  'O=C(C1=CC=CC=C1OC[H])O',
#  'O=C(O)C1=CC=CC=C1OC',
#  'C1=CC(=C(C=C1)C(O)=O)OC',
#  'C=1C=C(C=CC=1C(O)=O)CC(C)C',
#  'C1=CC=C(C(OC(C)=O)=C1)C(=O)OC',
#  'CC(=O)OC=1C=CC=CC=1C(C)=O',
#  'C1=CC=C(C(=C1)OC(=O)C)C(=O)C',
#  'CC(=O)C1=CC=CC=C1OC(=O)C',
#  'CNC(C1=CC=NC=C1)=O',
#  'O(C(=O)O)C1=CC=CC=C1C(=O)O',
#  'C(O)(=O)C=1C(=CC=CC=1)OC(=O)O',
#  'C=1C=CC=C(OC(=O)CC)C=1C(=O)O',
#  'O=C(OC)OC=1C(=CC=CC=1)C(=O)O',
#  'C(O)C(OC1=CC=CC=C1C(=O)O)=O',
#  'ONC(C=1C=CN=CC=1)=O',
#  'C1=CC(=CC=N1)C(NO)=O',
#  'CONC(C1=CC=NC=C1)=O',
#  'C=1C=C(C=CN=1)C(=O)NOC',
#  'C1(=CC=CC=C1OC(=O)C)C(=O)F',
#  'CCC=1C=CC(=CC=1)C(C)C(=O)O',
#  'C=1(C(C)C(=O)O)C=CC(CC[H])=CC=1',
#  'C=1C(=CC=C(C(C(=O)O)C)C=1)CC',
#  'C1(C(C)C(O)=O)=CC=C(C=C1)CC',
#  'CCC1=CC=C(C(C(=O)O)C)C=C1',
#  'CCC=1C=CC(C(C(=O)O)C)=CC=1',
#  'O=C(O)C(C)C=1C=CC(=CC=1)CC',
#  'C=1C=C(C(C)C(O)=O)C=CC=1CC',
#  'C(C)C=1C=CC(C(C(=O)O)C)=CC=1',
#  'CC(C(=O)O)C1=CC=C(C=C1)CC',
# ...
